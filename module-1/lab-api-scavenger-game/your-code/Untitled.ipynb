# %%
import json
import requests

response = requests.get('https://api.fifa.com/api/v1/calendar/matches?idseason=254645&idcompetition=17&language=en-GB&count=100')

results = response.json()
results
# Out:
# dict_keys(['ContinuationToken', 'ContinuationHash', 'Results'])

# %%
results['Results'][0]
# Out:
# {'IdCompetition': '17',
#  'IdSeason': '254645',
#  'IdStage': '275073',
#  'IdGroup': '275075',
#  'Weather': {'Humidity': '43',
#   'Temperature': '17',
#   'WindSpeed': '6',
#   'Type': 4,
#   'TypeLocalized': [{'Locale': 'en-GB', 'Description': 'Partly Cloudy'}]},
#  'Attendance': '78011',
#  'IdMatch': '300331503',
#  'MatchDay': '1',
#  'StageName': [{'Locale': 'en-GB', 'Description': 'First stage'}],
#  'GroupName': [{'Locale': 'en-GB', 'Description': 'Group A'}],
#  'CompetitionName': [{'Locale': 'en-GB', 'Description': 'FIFA World Cup™'}],
#  'SeasonName': [{'Locale': 'en-GB',
#    'Description': '2018 FIFA World Cup Russia™'}],
#  'SeasonShortName': [{'Locale': 'en-GB', 'Description': 'Russia 2018'}],
#  'Date': '2018-06-14T15:00:00Z',
#  'LocalDate': '2018-06-14T18:00:00Z',
#  'Home': {'Score': 5,
#   'Side': None,
#   'IdTeam': '43965',
#   'PictureUrl': 'https://api.fifa.com/api/v1/picture/flags-{format}-{size}/RUS',
#   'IdCountry': 'RUS',
#   'Tactics': '4-2-3-1',
# ...

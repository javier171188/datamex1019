# %%
import pandas as pd
import json
import requests

# %%
URL='https://api.github.com/repositories'
resp=requests.get(URL)
resp
# Out:
# <Response [200]>

# %%
data=pd.DataFrame(resp.json())
len(data)
# Out:
# 100

# %%
from pandas.io.json import json_normalize

flattened=json_normalize(resp.json())
flattened.head()
# Out:
#             id              type  public            created_at  actor.id  \
# 0  10784951654       DeleteEvent    True  2019-11-04T22:14:49Z  49699333
# 1  10784951648  PullRequestEvent    True  2019-11-04T22:14:49Z   3874064
# 2  10784951639         PushEvent    True  2019-11-04T22:14:49Z  46272257
# 3  10784951636         PushEvent    True  2019-11-04T22:14:49Z  30299792
# 4  10784951640       CreateEvent    True  2019-11-04T22:14:49Z  49700025
#
#        actor.login actor.display_login actor.gravatar_id  \
# 0  dependabot[bot]          dependabot
# 1    iamareebjamal       iamareebjamal
# 2       ecooke1970          ecooke1970
# 3   JulianSchroden      JulianSchroden
# 4     elvisknelson        elvisknelson
#
#                                       actor.url  \
# 0  https://api.github.com/users/dependabot[bot]
# 1    https://api.github.com/users/iamareebjamal
# 2       https://api.github.com/users/ecooke1970
# 3   https://api.github.com/users/JulianSchroden
# 4     https://api.github.com/users/elvisknelson
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/49699333?  ...
# 1   https://avatars.githubusercontent.com/u/3874064?  ...
# 2  https://avatars.githubusercontent.com/u/46272257?  ...
# 3  https://avatars.githubusercontent.com/u/30299792?  ...
# 4  https://avatars.githubusercontent.com/u/49700025?  ...
#
#    payload.comment.path payload.comment.commit_id  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
#
#   payload.comment.pull_request_review_id payload.comment.diff_hunk  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
#
#   payload.comment.original_position payload.comment.original_commit_id  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   payload.comment.pull_request_url  payload.comment._links.self.href  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   payload.comment._links.html.href  payload.comment._links.pull_request.href
# 0                              NaN                                       NaN
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
#
# [5 rows x 428 columns]
